# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %%
#https://www.kaggle.com/mirbektoktogaraev/madrid-real-estate-market?select=houses_Madrid.csv

# %% [markdown]
# ### Data exploration

# %%
df1 = pd.read_csv("./data/inputs/houses_Madrid.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  21742              Piso en venta en calle de Godella, 64
# 1           1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2           2  21740               Piso en venta en calle del Talco, 68
# 3           3  21739               Piso en venta en calle Pedro Jiménez
# 4           4  21738  Piso en venta en carretera de Villaverde a Val...
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid         64.0          60.0        2          1.0
# 1    Los Ángeles, Madrid         70.0           NaN        3          1.0
# 2     San Andrés, Madrid         94.0          54.0        2          2.0
# 3     San Andrés, Madrid         64.0           NaN        2          1.0
# 4    Los Rosales, Madrid        108.0          90.0        2          2.0
#
#    n_floors  sq_mt_allotment  ...  energy_certificate  has_parking  \
# ...

# %% [markdown]
# -----------

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'subtitle', 'sq_mt_built', 'sq_mt_useful',
#        'n_rooms', 'n_bathrooms', 'n_floors', 'sq_mt_allotment', 'latitude',
#        'longitude', 'raw_address', 'is_exact_address_hidden', 'street_name',
#        'street_number', 'portal', 'floor', 'is_floor_under', 'door',
#        'neighborhood_id', 'operation', 'rent_price', 'rent_price_by_area',
#        'is_rent_price_known', 'buy_price', 'buy_price_by_area',
#        'is_buy_price_known', 'house_type_id', 'is_renewal_needed',
#        'is_new_development', 'built_year', 'has_central_heating',
#        'has_individual_heating', 'are_pets_allowed', 'has_ac',
#        'has_fitted_wardrobes', 'has_lift', 'is_exterior', 'has_garden',
#        'has_pool', 'has_terrace', 'has_balcony', 'has_storage_room',
#        'is_furnished', 'is_kitchen_equipped', 'is_accessible',
#        'has_green_zones', 'energy_certificate', 'has_parking',
#        'has_private_parking', 'has_public_parking',
# ...

# %% [markdown]
# -----------

# %%
df1["raw_address"]
# Out:
# 0                           Calle de Godella, 64
# 1                Calle de la del Manojo de Rosas
# 2                            Calle del Talco, 68
# 3                            Calle Pedro Jiménez
# 4             Carretera de Villaverde a Vallecas
#                           ...
# 21737                                        NaN
# 21738    Urb. Campo de las Naciones - Corralejos
# 21739                                        NaN
# 21740                         Calle Burriana, 12
# 21741                      Calle San Epifanio, 9
# Name: raw_address, Length: 21742, dtype: object

# %% [markdown]
# ------------

# %%
df1["is_exact_address_hidden"]
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 21737     True
# 21738     True
# 21739     True
# 21740    False
# 21741    False
# Name: is_exact_address_hidden, Length: 21742, dtype: bool

# %% [markdown]
# -------------

# %%
df1["street_name"]
# Out:
# 0                               Calle de Godella
# 1                Calle de la del Manojo de Rosas
# 2                                Calle del Talco
# 3                            Calle Pedro Jiménez
# 4             Carretera de Villaverde a Vallecas
#                           ...
# 21737                                        NaN
# 21738    Urb. Campo de las Naciones - Corralejos
# 21739                                        NaN
# 21740                             Calle Burriana
# 21741                         Calle San Epifanio
# Name: street_name, Length: 21742, dtype: object

# %% [markdown]
# Tenemos que tener en cuenta que no podemos poner valor a una vivienda sin saber su ubicación, por ello vamos a eliminar todas las viviendas que no tengan una dirección.

# %%
df1.dropna(subset=["raw_address"],inplace=True)

# %% [markdown]
# #### Working with missing data

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0                          0
# id                                  0
# title                               0
# subtitle                            0
# sq_mt_built                        61
# sq_mt_useful                     9524
# n_rooms                             0
# n_bathrooms                        13
# n_floors                        15515
# sq_mt_allotment                 15632
# latitude                        16277
# longitude                       16277
# raw_address                         0
# is_exact_address_hidden             0
# street_name                       440
# street_number                    9977
# portal                          16277
# floor                            1485
# is_floor_under                    723
# door                            16277
# neighborhood_id                     0
# operation                           0
# rent_price                          0
# rent_price_by_area              16277
# is_rent_price_known                 0
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  21742              Piso en venta en calle de Godella, 64
# 1           1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2           2  21740               Piso en venta en calle del Talco, 68
# 3           3  21739               Piso en venta en calle Pedro Jiménez
# 4           4  21738  Piso en venta en carretera de Villaverde a Val...
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid         64.0          60.0        2          1.0
# 1    Los Ángeles, Madrid         70.0           NaN        3          1.0
# 2     San Andrés, Madrid         94.0          54.0        2          2.0
# 3     San Andrés, Madrid         64.0           NaN        2          1.0
# 4    Los Rosales, Madrid        108.0          90.0        2          2.0
#
#    n_floors  sq_mt_allotment  ...  energy_certificate  has_parking  \
# ...

# %% [markdown]
# Eliminamos aquellas columnas que no serán necesarias para nuestro objetivo.

# %%
df1 = df1.drop(columns=['Unnamed: 0', 'title',
       'sq_mt_allotment', 'is_exact_address_hidden', 'street_name',
       'street_number', 'portal', 'floor', 'is_floor_under', 'door',
       'neighborhood_id', 'operation', 'rent_price', 'rent_price_by_area',
       'is_rent_price_known','latitude','longitude',
       'is_buy_price_known', 'has_central_heating',
       'has_individual_heating', 'are_pets_allowed', 'has_ac',
       'has_fitted_wardrobes', 'has_lift',  'has_storage_room',
       'is_furnished', 'is_kitchen_equipped', 'is_accessible',
       'energy_certificate','sq_mt_useful', 'house_type_id',
       'has_private_parking', 'has_public_parking', 'has_green_zones',
       'is_parking_included_in_price', 'parking_price', 'is_orientation_north',
       'is_orientation_west', 'is_orientation_south', 'is_orientation_east'])

# %%
df1.head()
# Out:
#       id               subtitle  sq_mt_built  n_rooms  n_bathrooms  n_floors  \
# 0  21742  San Cristóbal, Madrid         64.0        2          1.0       NaN
# 1  21741    Los Ángeles, Madrid         70.0        3          1.0       NaN
# 2  21740     San Andrés, Madrid         94.0        2          2.0       NaN
# 3  21739     San Andrés, Madrid         64.0        2          1.0       NaN
# 4  21738    Los Rosales, Madrid        108.0        2          2.0       NaN
#
#                           raw_address  buy_price  buy_price_by_area  \
# 0                Calle de Godella, 64      85000               1328
# 1     Calle de la del Manojo de Rosas     129900               1856
# 2                 Calle del Talco, 68     144247               1535
# 3                 Calle Pedro Jiménez     109900               1717
# 4  Carretera de Villaverde a Vallecas     260000               2407
#
#    is_renewal_needed is_new_development  built_year is_exterior has_garden  \
# ...

# %%
df1 = df1.fillna(0) #Paso todos los valores NaN a 0

# %%
df1.head()
# Out:
#       id               subtitle  sq_mt_built  n_rooms  n_bathrooms  n_floors  \
# 0  21742  San Cristóbal, Madrid         64.0        2          1.0       0.0
# 1  21741    Los Ángeles, Madrid         70.0        3          1.0       0.0
# 2  21740     San Andrés, Madrid         94.0        2          2.0       0.0
# 3  21739     San Andrés, Madrid         64.0        2          1.0       0.0
# 4  21738    Los Rosales, Madrid        108.0        2          2.0       0.0
#
#                           raw_address  buy_price  buy_price_by_area  \
# 0                Calle de Godella, 64      85000               1328
# 1     Calle de la del Manojo de Rosas     129900               1856
# 2                 Calle del Talco, 68     144247               1535
# 3                 Calle Pedro Jiménez     109900               1717
# 4  Carretera de Villaverde a Vallecas     260000               2407
#
#    is_renewal_needed is_new_development  built_year is_exterior has_garden  \
# ...

# %%
df1 = df1 * 1 #Paso los True a valor 1 y los False a valor 0.
df1.head()
# Out:
#       id               subtitle  sq_mt_built  n_rooms  n_bathrooms  n_floors  \
# 0  21742  San Cristóbal, Madrid         64.0        2          1.0       0.0
# 1  21741    Los Ángeles, Madrid         70.0        3          1.0       0.0
# 2  21740     San Andrés, Madrid         94.0        2          2.0       0.0
# 3  21739     San Andrés, Madrid         64.0        2          1.0       0.0
# 4  21738    Los Rosales, Madrid        108.0        2          2.0       0.0
#
#                           raw_address  buy_price  buy_price_by_area  \
# 0                Calle de Godella, 64      85000               1328
# 1     Calle de la del Manojo de Rosas     129900               1856
# 2                 Calle del Talco, 68     144247               1535
# 3                 Calle Pedro Jiménez     109900               1717
# 4  Carretera de Villaverde a Vallecas     260000               2407
#
#    is_renewal_needed is_new_development  built_year is_exterior has_garden  \
# ...

# %%
df1["subtitle"].value_counts()
# Out:
# Malasaña-Universidad, Madrid               340
# Lavapiés-Embajadores, Madrid               319
# Ensanche de Vallecas - La Gavia, Madrid    305
# Prosperidad, Madrid                        293
# Pueblo Nuevo, Madrid                       282
#                                           ...
# Tetuán, Madrid                               2
# Arganzuela, Madrid                           2
# Puente de Vallecas, Madrid                   1
# Vicálvaro, Madrid                            1
# Barajas, Madrid                              1
# Name: subtitle, Length: 145, dtype: int64

# %%
df1.to_csv('./data/inputs/Madrid.csv')
